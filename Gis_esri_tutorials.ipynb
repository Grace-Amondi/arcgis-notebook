# %%
from arcgis.gis import GIS

# %%
gis = GIS("https://www.arcgis.com","Grace@Amondi","mypassword")

# %%
user = gis.users.get('Grace@Amondi')

# %%
user
# Out:
# <User username:Grace@Amondi>

# %%
createdDate = str(user['created'])

user['firstName'] + " " + user['lastName'] + "and joined in" + " " + str(user['created'])
# Out:
# 'Grace Amondiand joined in 1485936005000'

# %%
user.keys()
# Out:
# dict_keys(['storageQuota', 'fullName', 'description', 'orgId', 'tags', 'thumbnail', 'userType', 'groups', 'username', 'idpUsername', 'modified', 'provider', 'firstName', 'cultureFormat', 'lastLogin', 'region', 'favGroupId', 'id', 'created', 'roleId', 'userLicenseTypeId', 'level', 'lastName', 'preferredView', 'units', 'email', 'disabled', 'role', 'mfaEnabled', 'privileges', 'culture', 'access', 'storageUsage'])

# %%
map1= gis.map("Nairobi,KE")
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-b74c8051-3e40-4431-9d04-f7f0f018f5bb"><img src=""></img></div>

# %%
from IPython.display import display

items = gis.content.search('Rivers')
for item in items:
    display(item)
# Out:
# <Item title:"Meru County Resources and Infrastructure" type:Web Mapping Application owner:kelvinmunene>
# <Item title:"KIRINYAGA COUNTY MAP" type:Web Map owner:Beverly_kurgat>
# <Item title:"Kisumu_COunty_Online" type:Map Image Layer owner:osambadian>
# <Item title:"Kakamega County" type:Web Map owner:jokababa>
# <Item title:"nandi_county_map" type:Feature Layer Collection owner:bosire349>
# <Item title:"Kowiti" type:Map Image Layer owner:jokababa>
# <Item title:"Makueni_County" type:Map Image Layer owner:SOSPETERFRANCIS>
# <Item title:"Nyeri_county" type:Feature Layer Collection owner:edwardnjogu>
# <Item title:"Nyeri_county" type:Map Image Layer owner:edwardnjogu>
# <Item title:"lamu_county" type:Feature Layer Collection owner:Cleophas_mogeni>

# %%
item_to_add = [temp_item for temp_item in items if temp_item.title == 'lamu_county']
map1.add_layer(item_to_add[0])

# %%
type(gis.content)
# Out:
# arcgis.gis.ContentManager

# %%
gis.properties.availableCredits
# Out:
# -318.75186

# %%
gis.properties.name
# Out:
# 'Jomo Kenyatta University of Agriculture'

# %%
gis.content.is_service_name_available(service_name="awesome_gis",service_type="featureService")
# Out:
# True

# %%
my_service_name = gis.content.create_service(name="awesome_gis", service_type="featuresService")
my_service_name
# Out:
# <Item title:"awesome_gis" type:Feature Layer Collection owner:Grace@Amondi>

# %%
gis.content.create_folder(folder="tutorials")
# Out:
# {'id': 'db7801dd4b484175aa230d969343c231',
#  'title': 'tutorials',
#  'username': 'Grace@Amondi'}

# %%
my_service_name.move(folder="tutorials")
# Out:
# {'folder': 'db7801dd4b484175aa230d969343c231',
#  'itemId': '4da64850731648fe9f771a9df3a47345',
#  'owner': 'Grace@Amondi',
#  'success': True}

# %%
image = r'/home/grace/Pictures/index.jpg'
my_service_name.update(item_properties = {
    'tags':'python',
    'description':'gis is awesome',
},thumbnail= image)
# Out:
# True
